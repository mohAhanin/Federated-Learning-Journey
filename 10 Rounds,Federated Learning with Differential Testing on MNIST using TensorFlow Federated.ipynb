# %%
import collections
import numpy as np
import tensorflow as tf
import tensorflow_federated as tff
from scipy.stats import ks_2samp, chi2_contingency
import concurrent.futures

# Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# Normalize the data
X_train, X_test = X_train / 255.0, X_test / 255.0

# Define a model creation function
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Convert Keras model to TFF model
def model_fn():
    keras_model = create_model()
    return tff.learning.from_keras_model(
        keras_model,
        input_spec=client_datasets[0].element_spec,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
    )

# Create dummy client datasets
num_clients = 10
client_datasets = [tf.data.Dataset.from_tensor_slices((np.random.rand(100, 28, 28), np.random.randint(0, 10, 100))).batch(10) for _ in range(num_clients)]

# Create federated learning algorithms for each client
federated_algorithms = [tff.learning.build_federated_averaging_process(
    model_fn,
    client_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=0.02),
    server_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=1.0)
) for _ in range(num_clients)]

# Function to run the training in a separate event loop
def run_training():
    tff.backends.native.set_local_execution_context()

    states = [algorithm.initialize() for algorithm in federated_algorithms]

    # Train the models on the clients' data
    for round_num in range(1, 11):
        for client_id in range(num_clients):
            states[client_id], _ = federated_algorithms[client_id].next(states[client_id], [client_datasets[client_id]])

        # Perform differential testing for each pair of clients
        for i in range(num_clients):
            for j in range(i+1, num_clients):
                # Get the model weights after training
                weights_i = states[i].model.trainable
                weights_j = states[j].model.trainable

                # Evaluate both models on train and test data
                train_predictions_i, train_labels = evaluate_model_on_data(weights_i, create_model, X_train, Y_train)
                test_predictions_i, test_labels = evaluate_model_on_data(weights_i, create_model, X_test, Y_test)
                train_predictions_j, _ = evaluate_model_on_data(weights_j, create_model, X_train, Y_train)
                test_predictions_j, _ = evaluate_model_on_data(weights_j, create_model, X_test, Y_test)

                # Perform differential testing
                print(f"Comparison between Client {i} and Client {j}:")
                perform_differential_testing(train_predictions_i, train_predictions_j, train_labels, "Train")
                perform_differential_testing(test_predictions_i, test_predictions_j, test_labels, "Test")
                print()

# Function to evaluate the model on data
def evaluate_model_on_data(weights, create_model_fn, X, Y):
    model = create_model_fn()
    model.set_weights(weights)
    predictions = model.predict(X)
    return predictions, Y

# Function to perform differential testing
def perform_differential_testing(predictions_i, predictions_j, labels, data_type):
    # Criterion 1: Absolute differences between classes
    pred_class_i = np.argmax(predictions_i, axis=1)
    pred_class_j = np.argmax(predictions_j, axis=1)
    Δ_class = np.sum(pred_class_i != pred_class_j)

    # Criterion 2: Absolute differences between scores
    Δ_score = np.sum(predictions_i != predictions_j)

    # Criterion 3: Significance of difference between scores
    P_KS = ks_2samp(predictions_i.flatten(), predictions_j.flatten()).pvalue

    # Criterion 4: Significance of difference between classifications
    contingency = np.array([[np.sum((pred_class_i == k) & (pred_class_j == l)) for l in range(10)] for k in range(10)])
    contingency += 1  # Add-one smoothing
    P_X2 = chi2_contingency(contingency)[1]

    print(f"{data_type} Data:")
    print(f"Δ_class: {Δ_class}")
    print(f"Δ_score: {Δ_score}")
    print(f"P_KS: {P_KS}")
    print(f"P_X2: {P_X2}")
    
    if P_KS < 0.05 or P_X2 < 0.05:
        print("Warning: Significant difference detected (p-value < 0.05)")

# Run the training
with concurrent.futures.ThreadPoolExecutor() as executor:
    future = executor.submit(run_training)
    future.result()
# Out:
# Comparison between Client 0 and Client 1:
# Train Data:
# Δ_class: 49895
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8364
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.813648318831588e-108
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 2:
# Train Data:
# Δ_class: 54870
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9115
# Δ_score: 100000
# P_KS: 1.0063517584683998e-148
# P_X2: 1.0481630182941481e-192
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 3:
# Train Data:
# Δ_class: 49584
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8267
# Δ_score: 100000
# P_KS: 1.079202831691285e-158
# P_X2: 1.4638054479436146e-188
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 58859
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9805
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.1494759890888018e-136
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 59138
# Δ_score: 600000
# P_KS: 6.417091181944459e-76
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9859
# Δ_score: 100000
# P_KS: 4.68045860427684e-25
# P_X2: 9.12937404563366e-115
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 47318
# Δ_score: 600000
# P_KS: 2.717e-321
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7798
# Δ_score: 100000
# P_KS: 8.052134738739928e-71
# P_X2: 1.7216521726078027e-306
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 57583
# Δ_score: 600000
# P_KS: 5.244195209524132e-217
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9629
# Δ_score: 100000
# P_KS: 3.381997925771551e-35
# P_X2: 2.2458363096122475e-123
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 51910
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8567
# Δ_score: 100000
# P_KS: 6.519928236625078e-208
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 9:
# Train Data:
# Δ_class: 51808
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8645
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.5450074586961743e-181
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 2:
# Train Data:
# Δ_class: 52628
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8706
# Δ_score: 100000
# P_KS: 1.1717673254127318e-262
# P_X2: 7.076237237372167e-135
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 3:
# Train Data:
# Δ_class: 55574
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9219
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.8019830558637735e-97
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 4:
# Train Data:
# Δ_class: 56818
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9490
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 7.31074132419637e-83
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 5:
# Train Data:
# Δ_class: 54865
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9163
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.346899097918414e-123
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 6:
# Train Data:
# Δ_class: 49708
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8359
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.1693489976375523e-263
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 7:
# Train Data:
# Δ_class: 58430
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9775
# Δ_score: 100000
# P_KS: 1.775042834851617e-293
# P_X2: 1.3854384714555763e-111
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 8:
# Train Data:
# Δ_class: 53441
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8842
# Δ_score: 100000
# P_KS: 9.017612339467355e-69
# P_X2: 6.270458042363955e-225
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 9:
# Train Data:
# Δ_class: 53951
# Δ_score: 600000
# P_KS: 6.787018624770665e-19
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9010
# Δ_score: 100000
# P_KS: 0.005544731951234567
# P_X2: 5.576911566064056e-224
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 3:
# Train Data:
# Δ_class: 51521
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8517
# Δ_score: 100000
# P_KS: 1.255249e-317
# P_X2: 8.02641149047889e-216
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 4:
# Train Data:
# Δ_class: 55011
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9137
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.1817691557602318e-176
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 5:
# Train Data:
# Δ_class: 58376
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9701
# Δ_score: 100000
# P_KS: 6.896573460618107e-187
# P_X2: 3.232304355775228e-160
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 6:
# Train Data:
# Δ_class: 58242
# Δ_score: 600000
# P_KS: 3.4494262120523534e-303
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9703
# Δ_score: 100000
# P_KS: 8.190749587332457e-55
# P_X2: 2.49093398310538e-245
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 7:
# Train Data:
# Δ_class: 58333
# Δ_score: 600000
# P_KS: 3.4705978119517653e-295
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9698
# Δ_score: 100000
# P_KS: 1.0503947699367856e-56
# P_X2: 3.495514046354616e-151
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 8:
# Train Data:
# Δ_class: 55386
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9186
# Δ_score: 100000
# P_KS: 4.655501372534136e-67
# P_X2: 2.288991559710865e-252
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 9:
# Train Data:
# Δ_class: 52996
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8835
# Δ_score: 100000
# P_KS: 4.4170610909493265e-270
# P_X2: 1.1662780862076468e-259
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 4:
# Train Data:
# Δ_class: 55013
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9146
# Δ_score: 100000
# P_KS: 5.046024241561819e-91
# P_X2: 8.290994614993513e-207
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 5:
# Train Data:
# Δ_class: 59279
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 1.6958786802134227e-272
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9884
# Δ_score: 100000
# P_KS: 3.8832417693033326e-61
# P_X2: 5.221314371404173e-109
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 6:
# Train Data:
# Δ_class: 58925
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9826
# Δ_score: 100000
# P_KS: 6.726812339490801e-118
# P_X2: 1.5025291763782564e-187
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 7:
# Train Data:
# Δ_class: 57919
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9672
# Δ_score: 100000
# P_KS: 1.974782659885084e-229
# P_X2: 1.4771931129693367e-187
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 8:
# Train Data:
# Δ_class: 57221
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9527
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 8.138851827823527e-188
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 9:
# Train Data:
# Δ_class: 51972
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8652
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.3174853162962803e-115
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 5:
# Train Data:
# Δ_class: 57857
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9638
# Δ_score: 100000
# P_KS: 2.4115415714194626e-198
# P_X2: 2.9703708355554545e-165
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 6:
# Train Data:
# Δ_class: 57915
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9676
# Δ_score: 100000
# P_KS: 6.069422032502351e-142
# P_X2: 1.1120883405790173e-132
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 7:
# Train Data:
# Δ_class: 54234
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9094
# Δ_score: 100000
# P_KS: 4.98777393e-315
# P_X2: 2.7197352396445757e-133
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 8:
# Train Data:
# Δ_class: 58285
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9716
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.260061262443305e-136
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 9:
# Train Data:
# Δ_class: 55546
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9198
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 8.210598972314092e-231
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 6:
# Train Data:
# Δ_class: 47786
# Δ_score: 600000
# P_KS: 2.0005165661081883e-244
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7896
# Δ_score: 100000
# P_KS: 3.2930642920811427e-43
# P_X2: 3.897504028317494e-142
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 7:
# Train Data:
# Δ_class: 56692
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9496
# Δ_score: 100000
# P_KS: 2.1567064135148416e-68
# P_X2: 2.784328901134854e-172
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 8:
# Train Data:
# Δ_class: 46374
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7733
# Δ_score: 100000
# P_KS: 4.7371518549360165e-291
# P_X2: 2.5462602509317066e-183
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 9:
# Train Data:
# Δ_class: 57551
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9591
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.536328625978046e-165
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 7:
# Train Data:
# Δ_class: 57761
# Δ_score: 600000
# P_KS: 1.1387364425412173e-219
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9651
# Δ_score: 100000
# P_KS: 4.8107661607228625e-42
# P_X2: 1.560843513069567e-123
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 8:
# Train Data:
# Δ_class: 48959
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8132
# Δ_score: 100000
# P_KS: 9.522760898571255e-234
# P_X2: 1.9036505136263813e-225
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 9:
# Train Data:
# Δ_class: 57865
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9611
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.8992609008804823e-300
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 8:
# Train Data:
# Δ_class: 56111
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9343
# Δ_score: 100000
# P_KS: 4.553045526844249e-83
# P_X2: 1.5830162798571987e-178
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 9:
# Train Data:
# Δ_class: 44740
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7362
# Δ_score: 100000
# P_KS: 8.57818677589032e-299
# P_X2: 1.0900819845852364e-83
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 8 and Client 9:
# Train Data:
# Δ_class: 54015
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9028
# Δ_score: 100000
# P_KS: 5.832930139334971e-71
# P_X2: 5.106792019595374e-273
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 1:
# Train Data:
# Δ_class: 50267
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8417
# Δ_score: 100000
# P_KS: 1.214202094244064e-309
# P_X2: 3.189533970028632e-101
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 2:
# Train Data:
# Δ_class: 53297
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8825
# Δ_score: 100000
# P_KS: 2.1976046461173994e-125
# P_X2: 2.094238757680814e-196
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 3:
# Train Data:
# Δ_class: 46799
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7828
# Δ_score: 100000
# P_KS: 1.6261327614879217e-187
# P_X2: 2.0741171847885052e-170
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 58389
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9731
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.312657327556638e-116
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 59056
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9860
# Δ_score: 100000
# P_KS: 6.721353497155772e-92
# P_X2: 3.227857786164403e-100
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 49647
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8203
# Δ_score: 100000
# P_KS: 2.004344024684829e-130
# P_X2: 6.411261847120011e-294
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 57505
# Δ_score: 600000
# P_KS: 1.072984844007682e-155
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9629
# Δ_score: 100000
# P_KS: 7.29616210161165e-30
# P_X2: 2.3777001013431947e-115
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 52020
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8596
# Δ_score: 100000
# P_KS: 2.0606638619289727e-182
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 9:
# Train Data:
# Δ_class: 51120
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8523
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.0953565782789584e-185
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 2:
# Train Data:
# Δ_class: 52084
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8603
# Δ_score: 100000
# P_KS: 6.38579844460109e-236
# P_X2: 9.365187892728098e-146
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 3:
# Train Data:
# Δ_class: 55441
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9189
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.6649232876492245e-106
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 4:
# Train Data:
# Δ_class: 56282
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9404
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 7.259036444273387e-109
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 5:
# Train Data:
# Δ_class: 54518
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9103
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.4929736402869437e-127
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 6:
# Train Data:
# Δ_class: 50517
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8501
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.628090209556672e-266
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 7:
# Train Data:
# Δ_class: 58404
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9764
# Δ_score: 100000
# P_KS: 9.476834305289529e-259
# P_X2: 8.411917863331186e-130
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 8:
# Train Data:
# Δ_class: 53369
# Δ_score: 600000
# P_KS: 1.8745255551765626e-238
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8816
# Δ_score: 100000
# P_KS: 7.286759105532907e-37
# P_X2: 1.437205848967925e-242
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 9:
# Train Data:
# Δ_class: 53621
# Δ_score: 600000
# P_KS: 4.0820007107623435e-47
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8979
# Δ_score: 100000
# P_KS: 8.833777002294188e-08
# P_X2: 6.63490742142936e-247
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 3:
# Train Data:
# Δ_class: 51535
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8548
# Δ_score: 100000
# P_KS: 2.7921493519472944e-272
# P_X2: 2.0054109141113825e-211
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 4:
# Train Data:
# Δ_class: 55015
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9131
# Δ_score: 100000
# P_KS: 7.07969749476932e-300
# P_X2: 2.4788538921308477e-182
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 5:
# Train Data:
# Δ_class: 58384
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9711
# Δ_score: 100000
# P_KS: 2.0199858637713564e-228
# P_X2: 1.9826071157631608e-186
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 6:
# Train Data:
# Δ_class: 58393
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9722
# Δ_score: 100000
# P_KS: 1.1354241604550336e-81
# P_X2: 1.5213745296002507e-230
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 7:
# Train Data:
# Δ_class: 58337
# Δ_score: 599999
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9708
# Δ_score: 100000
# P_KS: 3.252818671312817e-62
# P_X2: 7.237008781860639e-148
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 8:
# Train Data:
# Δ_class: 54799
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9108
# Δ_score: 100000
# P_KS: 1.147863731396796e-90
# P_X2: 1.3143207874234935e-241
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 9:
# Train Data:
# Δ_class: 52486
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8749
# Δ_score: 100000
# P_KS: 5.4124170936701333e-303
# P_X2: 1.659736205193342e-252
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 4:
# Train Data:
# Δ_class: 54715
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9123
# Δ_score: 100000
# P_KS: 7.586998546928331e-81
# P_X2: 1.4863152843669527e-194
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 5:
# Train Data:
# Δ_class: 59411
# Δ_score: 600000
# P_KS: 1.546985183249861e-248
# P_X2: 8.711733267005794e-281
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9907
# Δ_score: 100000
# P_KS: 2.706928066471201e-39
# P_X2: 1.8942813043051872e-108
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 6:
# Train Data:
# Δ_class: 58855
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9808
# Δ_score: 100000
# P_KS: 1.7402531548026383e-87
# P_X2: 2.075810506365804e-182
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 7:
# Train Data:
# Δ_class: 57888
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9670
# Δ_score: 100000
# P_KS: 1.4736496772315946e-193
# P_X2: 4.0517934402290536e-170
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 8:
# Train Data:
# Δ_class: 56952
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9487
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.465479377983834e-181
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 9:
# Train Data:
# Δ_class: 52370
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8730
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 4.481412643761765e-118
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 5:
# Train Data:
# Δ_class: 58130
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9695
# Δ_score: 100000
# P_KS: 1.2218302802838572e-124
# P_X2: 3.3911130165815505e-185
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 6:
# Train Data:
# Δ_class: 56799
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9487
# Δ_score: 100000
# P_KS: 2.2291455545687935e-92
# P_X2: 8.502700876801846e-157
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 7:
# Train Data:
# Δ_class: 55075
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9200
# Δ_score: 100000
# P_KS: 4.831581104314526e-271
# P_X2: 3.359127819774967e-127
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 8:
# Train Data:
# Δ_class: 57828
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9660
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 9.348924805640176e-154
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 9:
# Train Data:
# Δ_class: 55619
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9215
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.105249601721236e-249
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 6:
# Train Data:
# Δ_class: 47833
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7917
# Δ_score: 100000
# P_KS: 4.754987207582113e-68
# P_X2: 9.123896757730632e-138
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 7:
# Train Data:
# Δ_class: 56426
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9427
# Δ_score: 100000
# P_KS: 1.042258084773342e-105
# P_X2: 3.1961457359235427e-170
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 8:
# Train Data:
# Δ_class: 47613
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7943
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 8.612062006727092e-188
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 9:
# Train Data:
# Δ_class: 57561
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9594
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.569207585854956e-155
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 7:
# Train Data:
# Δ_class: 57475
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9620
# Δ_score: 100000
# P_KS: 2.4047966702054274e-62
# P_X2: 5.883418954823686e-121
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 8:
# Train Data:
# Δ_class: 48912
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8146
# Δ_score: 100000
# P_KS: 5.863498022289895e-305
# P_X2: 6.581071561820443e-228
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 9:
# Train Data:
# Δ_class: 57841
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9617
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.9111771554770208e-282
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 8:
# Train Data:
# Δ_class: 55847
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9290
# Δ_score: 100000
# P_KS: 7.451575655386856e-105
# P_X2: 5.8656565171627474e-177
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 9:
# Train Data:
# Δ_class: 44304
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7287
# Δ_score: 100000
# P_KS: 1.42953e-319
# P_X2: 1.1108801653897434e-79
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 8 and Client 9:
# Train Data:
# Δ_class: 53802
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8991
# Δ_score: 100000
# P_KS: 9.908347276896202e-65
# P_X2: 1.6096837546210161e-267
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 1:
# Train Data:
# Δ_class: 49675
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8351
# Δ_score: 100000
# P_KS: 6.172756909403809e-178
# P_X2: 1.6637706241892075e-107
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 2:
# Train Data:
# Δ_class: 51850
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8588
# Δ_score: 100000
# P_KS: 6.823589328396816e-89
# P_X2: 3.974513510516184e-174
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 3:
# Train Data:
# Δ_class: 44686
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7467
# Δ_score: 100000
# P_KS: 1.0902934319884838e-192
# P_X2: 4.1364717115110976e-179
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 57998
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9658
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.7792975112555077e-127
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 58844
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9822
# Δ_score: 100000
# P_KS: 2.2513315512883386e-139
# P_X2: 2.918047670994067e-113
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 51539
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8537
# Δ_score: 100000
# P_KS: 7.02014256627664e-164
# P_X2: 5.943955887124765e-304
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 57284
# Δ_score: 599999
# P_KS: 9.212035196791885e-153
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9576
# Δ_score: 100000
# P_KS: 2.0784288530718487e-30
# P_X2: 7.16856462122533e-126
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 52617
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8702
# Δ_score: 100000
# P_KS: 3.771677452047675e-150
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 9:
# Train Data:
# Δ_class: 50860
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8485
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 7.254678636449719e-185
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 2:
# Train Data:
# Δ_class: 50895
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8394
# Δ_score: 100000
# P_KS: 1.0147711558347886e-163
# P_X2: 8.902040438391018e-147
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 3:
# Train Data:
# Δ_class: 54615
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9060
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.6729209297751117e-115
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 4:
# Train Data:
# Δ_class: 56312
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9401
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.9639473681947037e-126
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 5:
# Train Data:
# Δ_class: 55409
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9265
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.08035097708903e-141
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 6:
# Train Data:
# Δ_class: 51771
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8720
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 9.59779095188496e-290
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 7:
# Train Data:
# Δ_class: 58475
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9786
# Δ_score: 100000
# P_KS: 3.1341508613048945e-162
# P_X2: 1.0011750514944249e-147
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 8:
# Train Data:
# Δ_class: 53284
# Δ_score: 600000
# P_KS: 1.5617456463627935e-30
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8793
# Δ_score: 100000
# P_KS: 0.00018293305757296688
# P_X2: 2.937592452225184e-250
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 9:
# Train Data:
# Δ_class: 53022
# Δ_score: 600000
# P_KS: 2.2352303150068234e-229
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8879
# Δ_score: 100000
# P_KS: 7.941983278893119e-38
# P_X2: 1.22385145361446e-249
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 3:
# Train Data:
# Δ_class: 51514
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8589
# Δ_score: 100000
# P_KS: 2.1985322973359592e-218
# P_X2: 7.367628291169747e-204
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 4:
# Train Data:
# Δ_class: 55564
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9226
# Δ_score: 100000
# P_KS: 5.853698338467522e-285
# P_X2: 6.399183463847111e-176
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 5:
# Train Data:
# Δ_class: 58262
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9695
# Δ_score: 100000
# P_KS: 1.1771513704278124e-225
# P_X2: 1.3790229449260654e-188
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 6:
# Train Data:
# Δ_class: 58536
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9749
# Δ_score: 100000
# P_KS: 1.18883677824038e-97
# P_X2: 5.556875885184472e-211
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 7:
# Train Data:
# Δ_class: 58440
# Δ_score: 600000
# P_KS: 2.299910530119788e-258
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9729
# Δ_score: 100000
# P_KS: 2.1710274387616048e-49
# P_X2: 9.33649731565741e-157
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 8:
# Train Data:
# Δ_class: 54334
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9023
# Δ_score: 100000
# P_KS: 2.3725936517718254e-118
# P_X2: 4.405395101689626e-233
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 9:
# Train Data:
# Δ_class: 51981
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8654
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.6407858080694145e-247
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 4:
# Train Data:
# Δ_class: 55094
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9196
# Δ_score: 100000
# P_KS: 1.0889457110453238e-82
# P_X2: 1.1903548967500035e-182
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 5:
# Train Data:
# Δ_class: 59440
# Δ_score: 600000
# P_KS: 6.669854664742158e-212
# P_X2: 5.139811280467721e-280
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9903
# Δ_score: 100000
# P_KS: 2.63539578099683e-31
# P_X2: 1.4071245389636516e-109
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 6:
# Train Data:
# Δ_class: 58723
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9791
# Δ_score: 100000
# P_KS: 1.9510105240629197e-70
# P_X2: 7.4365734990282444e-183
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 7:
# Train Data:
# Δ_class: 57859
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9664
# Δ_score: 100000
# P_KS: 1.1827139066756977e-171
# P_X2: 6.65626189187009e-159
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 8:
# Train Data:
# Δ_class: 56912
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9503
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.8411002039606903e-177
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 9:
# Train Data:
# Δ_class: 52512
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8738
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 8.959947812669589e-119
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 5:
# Train Data:
# Δ_class: 58280
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9719
# Δ_score: 100000
# P_KS: 8.557684711755128e-106
# P_X2: 5.380121260437969e-195
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 6:
# Train Data:
# Δ_class: 55467
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9267
# Δ_score: 100000
# P_KS: 3.4571925072320375e-88
# P_X2: 2.4453150633338417e-170
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 7:
# Train Data:
# Δ_class: 55529
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9288
# Δ_score: 100000
# P_KS: 8.909370619134467e-289
# P_X2: 4.6424970178085135e-151
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 8:
# Train Data:
# Δ_class: 57425
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9581
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.421864665839988e-159
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 9:
# Train Data:
# Δ_class: 55726
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9229
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.017894651773577e-249
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 6:
# Train Data:
# Δ_class: 48114
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7967
# Δ_score: 100000
# P_KS: 7.684737354518883e-83
# P_X2: 3.5728197746172763e-146
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 7:
# Train Data:
# Δ_class: 55195
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9187
# Δ_score: 100000
# P_KS: 1.2452801073939018e-133
# P_X2: 3.3787048747921654e-184
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 8:
# Train Data:
# Δ_class: 48453
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8095
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 4.8632372912302194e-220
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 9:
# Train Data:
# Δ_class: 57476
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9595
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.3726673658186364e-154
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 7:
# Train Data:
# Δ_class: 56955
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9504
# Δ_score: 100000
# P_KS: 1.8109971829405697e-79
# P_X2: 9.924259134914018e-132
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 8:
# Train Data:
# Δ_class: 49005
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8161
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.1152884352217598e-244
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 9:
# Train Data:
# Δ_class: 57701
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9589
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 5.661033797090477e-285
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 8:
# Train Data:
# Δ_class: 55581
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9254
# Δ_score: 100000
# P_KS: 9.683723761803613e-123
# P_X2: 7.009208218642916e-191
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 9:
# Train Data:
# Δ_class: 44602
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7356
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 7.616933186261277e-93
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 8 and Client 9:
# Train Data:
# Δ_class: 53888
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8992
# Δ_score: 100000
# P_KS: 7.725163341685553e-63
# P_X2: 3.8161435502423964e-288
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 1:
# Train Data:
# Δ_class: 49101
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8239
# Δ_score: 100000
# P_KS: 6.074054495012938e-124
# P_X2: 2.3851969657647755e-119
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 2:
# Train Data:
# Δ_class: 49803
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8244
# Δ_score: 100000
# P_KS: 2.3068881937827887e-59
# P_X2: 1.1014591842366531e-167
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 3:
# Train Data:
# Δ_class: 44072
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7328
# Δ_score: 100000
# P_KS: 4.1215035023722824e-175
# P_X2: 7.601678510926866e-198
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 57598
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9605
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 6.795174290866122e-132
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 58555
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9770
# Δ_score: 100000
# P_KS: 4.7403699646778e-198
# P_X2: 3.3348167546509748e-130
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 52784
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8770
# Δ_score: 100000
# P_KS: 5.934342859565149e-218
# P_X2: 2.8275344273581403e-305
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 57008
# Δ_score: 600000
# P_KS: 5.902952382349726e-190
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9528
# Δ_score: 100000
# P_KS: 4.487290932943741e-35
# P_X2: 1.44012867188851e-122
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 53082
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8767
# Δ_score: 100000
# P_KS: 5.254419079435074e-133
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 9:
# Train Data:
# Δ_class: 50968
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8516
# Δ_score: 100000
# P_KS: 8.765393228715274e-298
# P_X2: 6.825011998299637e-196
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 2:
# Train Data:
# Δ_class: 49633
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8191
# Δ_score: 100000
# P_KS: 2.7141675973215888e-136
# P_X2: 5.762613432659706e-147
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 3:
# Train Data:
# Δ_class: 54067
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8956
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.093835076850353e-115
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 4:
# Train Data:
# Δ_class: 56079
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9380
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.2341744044575876e-152
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 5:
# Train Data:
# Δ_class: 55719
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9328
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.645751370026103e-142
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 6:
# Train Data:
# Δ_class: 52442
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8855
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 5.437053198925751e-306
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 7:
# Train Data:
# Δ_class: 58560
# Δ_score: 599999
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9793
# Δ_score: 100000
# P_KS: 1.050335575063947e-140
# P_X2: 5.097285669246116e-151
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 8:
# Train Data:
# Δ_class: 53157
# Δ_score: 600000
# P_KS: 1.7573270318875588e-10
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8816
# Δ_score: 100000
# P_KS: 0.002953429542786481
# P_X2: 1.056293836955522e-275
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 9:
# Train Data:
# Δ_class: 52761
# Δ_score: 600000
# P_KS: 0.0
# ...
# Δ_score: 100000
# P_KS: 1.3268450493620598e-194
# P_X2: 2.7408974822775106e-216
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 57303
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9565
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.5753095278975577e-136
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 58048
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9662
# Δ_score: 100000
# P_KS: 2.4072158759640647e-267
# P_X2: 8.688429639380007e-125
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 53379
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8900
# Δ_score: 100000
# P_KS: 1.4851296430070382e-264
# P_X2: 1.1614765865648593e-293
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 57023
# Δ_score: 600000
# P_KS: 3.356459962296345e-236
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9524
# Δ_score: 100000
# P_KS: 9.372534460378822e-46
# P_X2: 4.643399159934713e-132
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 53158
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8798
# Δ_score: 100000
# P_KS: 8.450727194363988e-115
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 9:
# Train Data:
# Δ_class: 51160
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8554
# Δ_score: 100000
# P_KS: 5.264152634933405e-272
# P_X2: 2.545637138647497e-184
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 2:
# Train Data:
# Δ_class: 48208
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7943
# Δ_score: 100000
# P_KS: 1.990677600630363e-129
# P_X2: 1.6196038637271614e-143
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 3:
# Train Data:
# Δ_class: 53133
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8797
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.8051403112236802e-120
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 4:
# Train Data:
# Δ_class: 55864
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9359
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.286875580181266e-176
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 5:
# Train Data:
# Δ_class: 55961
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9355
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.9806619525348598e-174
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 6:
# Train Data:
# Δ_class: 52896
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8931
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 7:
# Train Data:
# Δ_class: 58633
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9796
# Δ_score: 100000
# P_KS: 2.7047983884594535e-110
# P_X2: 2.862129522916597e-162
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 8:
# Train Data:
# Δ_class: 53157
# Δ_score: 599999
# P_KS: 6.365838111383416e-51
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8829
# Δ_score: 100000
# P_KS: 3.425954977634314e-14
# P_X2: 4.50860520467669e-283
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 1 and Client 9:
# Train Data:
# Δ_class: 52868
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8847
# Δ_score: 99999
# P_KS: 3.470770032266927e-102
# P_X2: 9.50991932145122e-279
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 3:
# Train Data:
# Δ_class: 49139
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8143
# Δ_score: 100000
# P_KS: 2.2146383491632832e-91
# P_X2: 7.346640918268984e-189
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 4:
# Train Data:
# Δ_class: 57409
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9529
# Δ_score: 99999
# P_KS: 1.9911193978588937e-183
# P_X2: 8.198197910623567e-149
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 5:
# Train Data:
# Δ_class: 58155
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9688
# Δ_score: 100000
# P_KS: 1.8100789557081343e-182
# P_X2: 3.527366609745962e-172
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 6:
# Train Data:
# Δ_class: 58819
# Δ_score: 599999
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9818
# Δ_score: 100000
# P_KS: 8.31063008102181e-130
# P_X2: 6.935535955226056e-169
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 7:
# Train Data:
# Δ_class: 58791
# Δ_score: 600000
# P_KS: 5.4517660319898776e-133
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9792
# Δ_score: 100000
# P_KS: 1.5758883938319462e-23
# P_X2: 3.855027699097023e-153
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 8:
# Train Data:
# Δ_class: 53820
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8919
# Δ_score: 100000
# P_KS: 3.733714292119041e-224
# P_X2: 1.971691478370342e-204
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 2 and Client 9:
# Train Data:
# Δ_class: 50534
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8379
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 8.855638478561686e-235
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 4:
# Train Data:
# Δ_class: 56028
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9352
# Δ_score: 100000
# P_KS: 4.411600313114202e-75
# P_X2: 3.2536703919935594e-184
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 5:
# Train Data:
# Δ_class: 59510
# Δ_score: 600000
# P_KS: 1.137339553633264e-194
# P_X2: 5.4944186811179014e-303
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9914
# Δ_score: 100000
# P_KS: 8.096830468143569e-30
# P_X2: 3.1581402942010312e-109
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 6:
# Train Data:
# Δ_class: 58460
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9748
# Δ_score: 100000
# P_KS: 1.7689002894358283e-75
# P_X2: 6.565020171838582e-177
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 7:
# Train Data:
# Δ_class: 57838
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9656
# Δ_score: 100000
# P_KS: 2.94059709851572e-96
# P_X2: 2.2298801104025366e-134
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 8:
# Train Data:
# Δ_class: 56813
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9494
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 3.767594364467131e-171
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 3 and Client 9:
# Train Data:
# Δ_class: 52551
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8728
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 7.73603694608046e-117
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 5:
# Train Data:
# Δ_class: 58599
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9760
# Δ_score: 100000
# P_KS: 4.454608575049145e-73
# P_X2: 1.1287706803440436e-192
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 6:
# Train Data:
# Δ_class: 52239
# Δ_score: 600000
# P_KS: 2.4816853651819837e-224
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8712
# Δ_score: 100000
# P_KS: 1.9085138081353548e-50
# P_X2: 1.0675947509849826e-209
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 7:
# Train Data:
# Δ_class: 56301
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9404
# Δ_score: 100000
# P_KS: 1.321681655940691e-203
# P_X2: 4.687224942747521e-166
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 8:
# Train Data:
# Δ_class: 56376
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9385
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 5.2914099729861726e-219
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 4 and Client 9:
# Train Data:
# Δ_class: 55743
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9249
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.1306481409898597e-272
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 6:
# Train Data:
# Δ_class: 48979
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8110
# Δ_score: 100000
# P_KS: 3.0263950357182133e-128
# P_X2: 5.309158566894698e-163
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 7:
# Train Data:
# Δ_class: 52773
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8780
# Δ_score: 100000
# P_KS: 4.999075543053581e-163
# P_X2: 5.829632842151094e-157
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 8:
# Train Data:
# Δ_class: 50029
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8353
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 5.7335216673124844e-241
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 5 and Client 9:
# Train Data:
# Δ_class: 57523
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9623
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.5952293606091286e-165
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 7:
# Train Data:
# Δ_class: 55845
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9302
# Δ_score: 100000
# P_KS: 1.2437545780862486e-94
# P_X2: 5.205466569505289e-136
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 8:
# Train Data:
# Δ_class: 49112
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8158
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 6.825522504580732e-279
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 6 and Client 9:
# Train Data:
# Δ_class: 57540
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9584
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 2.204906562469727e-297
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 8:
# Train Data:
# Δ_class: 54786
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9117
# Δ_score: 100000
# P_KS: 1.380774140913742e-196
# P_X2: 4.528120524312717e-185
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 7 and Client 9:
# Train Data:
# Δ_class: 44320
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7307
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 6.159625214341206e-97
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 8 and Client 9:
# Train Data:
# Δ_class: 54400
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9088
# Δ_score: 100000
# P_KS: 1.9059618540365134e-45
# P_X2: 6.404879130363338e-305
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 1:
# Train Data:
# Δ_class: 47845
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7956
# Δ_score: 100000
# P_KS: 7.325501017075096e-57
# P_X2: 2.4157100836895653e-150
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 2:
# Train Data:
# Δ_class: 46700
# Δ_score: 600000
# P_KS: 1.1657172097823288e-199
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 7798
# Δ_score: 100000
# P_KS: 1.7557188828317863e-43
# P_X2: 1.198461512068584e-181
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 3:
# Train Data:
# Δ_class: 41787
# Δ_score: 599999
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 6955
# Δ_score: 100000
# P_KS: 5.727687930575773e-134
# P_X2: 1.5512996104281955e-209
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 4:
# Train Data:
# Δ_class: 57146
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9542
# Δ_score: 100000
# P_KS: 0.0
# P_X2: 1.0800803004745641e-154
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 5:
# Train Data:
# Δ_class: 57423
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9536
# Δ_score: 100000
# P_KS: 1.6268997343950808e-299
# P_X2: 1.492769025788567e-129
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 6:
# Train Data:
# Δ_class: 54067
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9005
# Δ_score: 100000
# P_KS: 1.0779314338282804e-272
# P_X2: 8.475045956511495e-295
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 7:
# Train Data:
# Δ_class: 56355
# Δ_score: 600000
# P_KS: 2.1928307634837645e-247
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 9414
# Δ_score: 100000
# P_KS: 4.692221718254338e-47
# P_X2: 5.058292267159826e-148
# Warning: Significant difference detected (p-value < 0.05)
#
# Comparison between Client 0 and Client 8:
# Train Data:
# Δ_class: 53538
# Δ_score: 600000
# P_KS: 0.0
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)
# Test Data:
# Δ_class: 8861
# Δ_score: 100000
# P_KS: 4.497854714254272e-109
# P_X2: 0.0
# Warning: Significant difference detected (p-value < 0.05)

# %% [markdown]
# This code implements a federated learning setup where each client has its own model implementation. It then performs differential testing to compare the behavior of these different implementations, both on training and test data. This allows for detecting significant differences or potential errors in the various client implementations of the same algorithm.

# %% [markdown]
# Imports:
# The code imports necessary libraries including TensorFlow, TensorFlow Federated, NumPy, SciPy, and concurrent.futures.
# Data Loading and Preprocessing:
#
# The MNIST dataset is loaded using TensorFlow's keras API.
# The pixel values are normalized by dividing by 255.0.
#
#
# Model Definition:
#
# A function create_model() defines a simple neural network using Keras Sequential API.
# The model has a Flatten layer, a Dense layer with 128 units and ReLU activation, a Dropout layer, and a final Dense layer with 10 units (for 10 digit classes) and softmax activation.
#
#
# TensorFlow Federated (TFF) Model Conversion:
#
# The model_fn() function converts the Keras model to a TFF model.
# It specifies the loss function (SparseCategoricalCrossentropy) and metrics (SparseCategoricalAccuracy).
#
#
# Client Dataset Creation:
#
# 10 dummy client datasets are created using random data.
# Each client has 100 samples of 28x28 images and corresponding labels.
#
#
# Federated Learning Algorithms:
#
# A separate federated learning algorithm is created for each client using tff.learning.build_federated_averaging_process().
# This implements the Federated Averaging algorithm for each client.
#
#
# Training Function (run_training()):
#
# Sets up the TFF local execution context.
# Initializes the state for each client's federated learning algorithm.
# Runs 10 rounds of training, where in each round:
#
# Each client's model is updated using their own data.
# After updating, differential testing is performed between each pair of clients.
#
#
#
#
# Model Evaluation Function:
#
# evaluate_model_on_data() takes model weights, creates a new model, sets the weights, and makes predictions on given data.
#
#
# Differential Testing Function:
#
# perform_differential_testing() compares predictions from two client models.
# It calculates four criteria:
# a. Δ_class: The number of samples where the two models predict different classes.
# b. Δ_score: The sum of absolute differences between the models' prediction scores.
# c. P_KS: p-value from a Kolmogorov-Smirnov test comparing the distribution of prediction scores.
# d. P_X2: p-value from a Chi-squared test comparing the distribution of predicted classes.
# It prints these values and warns if either p-value is less than 0.05, indicating a significant difference between the models.
#
#
# Main Execution:
#
# The training function is run in a separate thread using concurrent.futures.ThreadPoolExecutor.
